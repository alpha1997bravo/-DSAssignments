# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('wc-at (1).csv')

# %%
df.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
sns.histplot(data = df, x='AT', kde=True,color='green')
# Out:
# <Axes: xlabel='AT', ylabel='Count'>

# %%
sns.histplot(data = df, x='Waist', kde=True,color='green')
# Out:
# <Axes: xlabel='Waist', ylabel='Count'>
